# %% [markdown]
# # Setup

# %%
# stop Colab backend from disconnecting
# %%javascript
function ClickConnect(){
console.log("Working");
document.querySelector("colab-toolbar-button#connect").click()
}setInterval(ClickConnect,60000)
# Out:
#   File "<ipython-input-92-0873f9263e22>", line 4
#     function ClickConnect(){
#                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Install and import libraries

# %%
# !pip3 install emnist
# !pip3 install fastprogress
# !pip3 install matplotlib==3.3.2
# !pip3 install cleverhans
# Out:
# Requirement already satisfied: emnist in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from emnist) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from emnist) (1.18.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from emnist) (4.41.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->emnist) (1.24.3)
# Requirement already satisfied: fastprogress in /usr/local/lib/python3.6/dist-packages (1.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fastprogress) (1.18.5)

# %%
from fastprogress import master_bar, progress_bar

import emnist

import numpy as np
import pandas as pd

import tensorflow as tf
import sklearn
import sklearn.metrics
import sklearn.model_selection

import matplotlib.pyplot as plt
import seaborn as sns


# from cleverhans.attacks import FastGradientMethod, BasicIterativeMethod
# from clevehans.utils_keras import KerasModelWrapper

# %% [markdown]
# ## GPU Warmup

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))

def gpu_warmup():
  with tf.device('/device:GPU:0'):
    random_image = tf.random.normal((100,100,100,3))
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image)
    return tf.math.reduce_sum(net_gpu)

gpu_warmup()

# %%
# check which GPU you are using
gpu_attributes = tf.python.client.device_lib.list_local_devices()[-1]
print(gpu_attributes.physical_device_desc)
# Out:
# device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %% [markdown]
# ## Mount Google Drive

# %% [markdown]
# Google Drive is mounted to take advantage of Google's *blazing* fast upload and download speeds to store the model and adversarial sets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Set Constants

# %%
ROOT = '/content/drive/My Drive/Colab Notebooks'
STD_VALS = np.array(range(5, 40, 5)) / 100
SEED = 30034

# %%
fp = ROOT + '/Data/emnist-balanced-mapping.txt'
ascii_class_mapping = pd.read_csv(fp, sep=' ', header=None,).set_index(keys=0).squeeze().apply(chr).to_dict()

# %% [markdown]
# # Load and Peek at data

# %%
emnist.list_datasets()
# Out:
# ['balanced', 'byclass', 'bymerge', 'digits', 'letters', 'mnist']

# %%
data_subset = 'balanced'
X_train, y_train = emnist.extract_training_samples(data_subset)
X_test, y_test = emnist.extract_test_samples(data_subset)

# %%
TRAIN_SIZE = X_train.shape[0]
WIDTH = X_train.shape[1]
HEIGHT = X_train.shape[2]
IMG_SHAPE = (WIDTH, HEIGHT)

# %%
def show_9_samples(X):
  random_ids = np.random.randint(low=0, high=len(X), size=9)
  print('Randomly selected indices: ', random_ids)
  for placement, id in enumerate(random_ids):
    plt.subplot(330+1+placement)
    plt.imshow(X[id].reshape(IMG_SHAPE), cmap=plt.get_cmap('gray'))
  plt.show()

# %%
show_9_samples(X_train)
# Out:
# Randomly selected indices:  [62634 32626 89367 61745 28908 58595 62471 38369 94835]

# %%
X_train_origin = X_train.reshape((X_train.shape[0], WIDTH, HEIGHT, 1)).astype('float32') / 255.0
X_test_origin = X_test.reshape((X_test.shape[0], WIDTH, HEIGHT, 1)).astype('float32') / 255.0
y_train_origin = tf.keras.utils.to_categorical(y_train)
y_test_origin = tf.keras.utils.to_categorical(y_test)

# %%
INPUT_SHAPE = X_train_origin.shape[1:]
N_CLASSES = y_test_origin.shape[1]

# %% [markdown]
# # CNN Model

# %% [markdown]
# ## Define the model

# %%
def make_cnn_7conv_1dense(name):
    
    model = tf.keras.models.Sequential()

    model._name = name

    model.add(tf.keras.layers.Conv2D(32, kernel_size = 3, activation='relu', input_shape = INPUT_SHAPE))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(32, kernel_size = 3, activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(32, kernel_size = 5, strides=2, padding='same', activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dropout(0.4))

    model.add(tf.keras.layers.Conv2D(64, kernel_size = 3, activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(64, kernel_size = 3, activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(64, kernel_size = 5, strides=2, padding='same', activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dropout(0.4))

    model.add(tf.keras.layers.Conv2D(128, kernel_size = 4, activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dropout(0.4))
               
    model.add(tf.keras.layers.Dense(N_CLASSES, activation='softmax'))
    
    adam = tf.keras.optimizers.Adam(lr = 0.001)
    model.compile(
        optimizer = adam, 
        loss = 'categorical_crossentropy', 
        metrics = [
          'accuracy',
          'Precision',
          'Recall',
        ]
    )
    
    return model

# %% [markdown]
# ## Fit regular CNN on normal data

# %%
# instantiate model
cnn = make_cnn_7conv_1dense(name='cnn_7conv_1dense')
cnn.summary()

# %%
# train-validation split
X_train_origin_train, X_train_origin_validation, \
y_train_origin_train, y_train_origin_validation =\
sklearn.model_selection.train_test_split(
    X_train_origin,
    y_train_origin,
    test_size=0.2,
    random_state=SEED,
    stratify=y_train,
)

# %%
# %%time

# define callbacks
checkpointer = tf.keras.callbacks.ModelCheckpoint(
    ROOT + '/Models/' + cnn._name + '-checkpoint-ep{epoch:02d}-loss{val_loss:.2f}',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1,
)

stopper = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True,
)

lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=2,
    verbose=1,
)

# fit the Model
BATCH_SIZE = 1024,
history_cnn = cnn.fit(
    x=X_train_origin, 
    y=y_train_origin,
    # augmentation_generator.flow(
    #     X_train_origin_train, y_train_origin_train, 
    # ),
    # validation_data=(X_train_origin_validation, y_train_origin_validation),
    validation_split=0.2,
    epochs=50,
    batch_size=32,
    callbacks = [checkpointer, stopper, lr_reducer],
    verbose=1
)

# save the model and training history
model_name = cnn_7conv_1dense._name
cnn.save(ROOT+'/Models/'+ model_name)
pd.DataFrame(history_cnn.history).to_csv(ROOT+'/model_histories/'+ model_name + '_history.csv')

# evaluate accuracy
accuracy = cnn.evaluate(X_test_origin, y_test_origin, verbose=0)

print("Baseline Error: %.2f%%" % (100-accuracy[1]*100))
print(f'Test loss for base CNN: {accuracy[0]} / Test accuracy: {accuracy[1]}')

# %% [markdown]
# ## Alternatively, load fitted model

# %%
location = '/Models/sequential'

cnn = tf.keras.models.load_model(
    ROOT + location,
)

# %% [markdown]
# ## Plot its learning curve

# %%
def show_learning_curve(history, clf_name):

  with sns.axes_style('darkgrid'):
    fig, ax = plt.subplots()

  sns.lineplot(
    data=pd.DataFrame(history.history),
    ax=ax,
    dashes=True,
    hue_order=[
      'accuracy',
      'val_accuracy',
      'loss',
      'val_loss',
    ],
    palette='mako',
  )

  ax.set_title(f'{clf_name} Learning Curve', size='xx-large', pad=10,)
  ax.set_xlabel('# epochs')
  ax.set_ylabel('Accuracy / Loss')

  return fig

# %%
regular_learning_fig =show_learning_curve(history=history_cnn)

# %% [markdown]
# ## Confusion Matrix

# %%
def show_confusion(model, X_eval, y_true, clf_desc, X_desc):

  # calculate confusion, precision and recal
  y_pred = model.predict_classes(X_eval)

  confusion_matrix = sklearn.metrics.confusion_matrix(
      y_true=y_true,
      y_pred=y_pred,
      normalize='true',
  )

  precision = sklearn.metrics.precision_score(
      y_true=y_true,
      y_pred=y_pred,
      average=None,
  )

  recall = sklearn.metrics.recall_score(
      y_true=y_true,
      y_pred=y_pred,
      average=None,
  )
  # set results into a dataframe
  marginals_df = pd.DataFrame({
    'class': ascii_class_mapping.values(),
    'precision': precision,
    'recall': recall,
  })

  # plot the confusion matrix
  with sns.axes_style('white'):
    fig = plt.figure(constrained_layout=True)
    fig.set_size_inches(h=11, w=10)
    gs = fig.add_gridspec(
      nrows=3, ncols=2, width_ratios=[16,1], height_ratios=[1,16, 0.3],
      wspace=0.01, hspace=0.01
    )
    marg_x_ax = fig.add_subplot(gs[0, :-1])
    marg_y_ax = fig.add_subplot(gs[1:-1, -1])
    joint_ax = fig.add_subplot(gs[1:-1, 0:-1])
    cbar_ax = fig.add_subplot(gs[-1,:-1])

    default_color = sns.color_palette('mako', 50)[-1]
    accent_color = sns.color_palette('mako', 30)[-5]

    sns.barplot(
        data=marginals_df,
        y='precision',
        x='class',
        ax=marg_x_ax,
        color=default_color,
    )
    marg_x_ax.set_title('Precision', size='small')
    marg_x_ax.get_xaxis().set_visible(False)
    marg_x_ax.get_yaxis().set_visible(False)
    marg_x_ax.axhline(y=1, color=accent_color, dashes=(5,3), label='100%')
    sns.despine(ax=marg_x_ax, left=True, bottom=True)

    sns.barplot(
        data=marginals_df,
        x='recall',
        y='class',
        ax=marg_y_ax,
        color=default_color,
    )
    marg_y_ax.set_title('Recall', size='small')
    marg_y_ax.get_xaxis().set_visible(False)
    marg_y_ax.get_yaxis().set_visible(False)
    marg_y_ax.axvline(x=1, color=accent_color, dashes=(5,3), label='100%')
    sns.despine(ax=marg_y_ax, left=True, bottom=True)

    sns.heatmap(
        confusion_matrix,
        ax=joint_ax,
        xticklabels=ascii_class_mapping.values(),
        yticklabels=ascii_class_mapping.values(),
        cmap='mako_r',
        cbar=True,
        cbar_ax=cbar_ax,
        cbar_kws={
            'orientation': 'horizontal',
            'shrink' : 0.7,
            'fraction': 0.05,
            'aspect': 40,
        },
        annot=False,
        fmt='.1f',
        annot_kws={
            'alpha': 0.8,
            'fontsize': 10,
        },
        # square=True,
        linecolor='white',
        linewidth=0.004,
    )  
  joint_ax.tick_params(bottom=False, left=False, labeltop=True, labelright=True, labelrotation=0.0)
  joint_ax.set_ylabel('True class label', size='medium', labelpad=10)
  joint_ax.set_xlabel('Predicted class label', size='medium', labelpad=10)

  cbar_ax.set_xlabel('True proportion identified', size='small')
  fig.suptitle(f'{clf_desc} Confusion Matrix for {X_desc}', size='xx-large', va='top', )

  return fig

# %%
fig = show_confusion(
    model=cnn, 
    X_eval=X_test_origin,
    y_true=y_test,
    clf_desc='CNN',
    X_desc='Held-out Test Set'
)

# %% [markdown]
# # Gaussian noise adversary

# %% [markdown]
# ## Create Noisy Datasets

# %% [markdown]
# ### Noise-addition function def'ns

# %%
def show_img_before_after(before, after, kind=''):
    fig, ax = plt.subplots(ncols=2)
    ax[0].imshow(before, cmap=plt.get_cmap('gray'))
    ax[0].set_title('Original')
    ax[1].imshow(after, cmap=plt.get_cmap('gray'))
    noisy_title = f'With {kind} Noise'
    ax[1].set_title(noisy_title)

# %%
def add_gaussian_noise(original_img, sd=0.1):
  # add noise
  img_shape = original_img.shape
  original_img = original_img.copy()
  gauss = np.random.normal(0, sd, img_shape)
  new_img = original_img + gauss
  # rescale between 0-1
  img_min = new_img.min()
  img_max = new_img.max()
  new_img = (new_img - img_min) / (img_max - img_min)
  return new_img

# %%
def add_speckle_noise(original_img):
  img_shape = original_img.shape
  original_img = original_img.copy()
  if img_shape.count == 3:
    row, col, ch = img_shape
    guass = np.random.randn(row, col, ch)
    guass = guass.reshape(row, col, ch)
    noisy_img = original_img + original_img*guass
  else:
    guass = np.random.normal(0, 1, img_shape)
    noisy_img = original_img + original_img*guass
  # rescale between 0-1
  img_min = noisy_img.min()
  img_max = noisy_img.max()
  noisy_img = (noisy_img - img_min) / (img_max - img_min)
  return noisy_img

# %%
def add_impulse_noise(img, signal_noise, salt_pepper_ratio=0.5):
  shape = img.shape
  img = img.copy()
  unif = np.random.uniform(low=0, high=1, size=shape)
  total_noise = 1-signal_noise

  salt_amount = total_noise * salt_pepper_ratio
  salted = np.where(unif<salt_amount, 1, img)

  pepper_amount = total_noise * (1-salt_pepper_ratio)
  peppered = np.where(unif>1-pepper_amount, 0, salted)
  
  return peppered

# %% [markdown]
# ### Preview generate-able noise types

# %%
# demo
img = X_train_origin[103728]
show_img_before_after(img.reshape((28, 28)), add_gaussian_noise(img, 0.10).reshape((28, 28)), kind='Gaussian')
show_img_before_after(img.reshape((28, 28)), add_speckle_noise(img).reshape((28, 28)), kind='Speckle')
show_img_before_after(img.reshape((28, 28)), add_impulse_noise(img, 0.9).reshape((28, 28)), kind='Impulse')

# %% [markdown]
# ### Create and save the noisy examples

# %%
def add_gauss_to_data(std_range, X_original, name):
  std_range = np.array(std_range)
  sd_names =  [f'{int(val*100):02}' for val in std_range]

  for i, sd in enumerate(std_range): 
    X_gauss = np.zeros(shape=X_original.shape)
    
    for j, img in enumerate(X_original):
      X_gauss[j] = add_gaussian_noise(img, sd=sd)

    fname = f'X_{name}_gauss_{sd_names[i]}'
    print(fname)
    np.save(ROOT + f'/Adversarial_Data/{fname}', X_gauss)

# %%
# %%time
add_gauss_to_data(
    std_range=np.array([0.3]), 
    X_original=X_test_origin, 
    name='test'
)
# Out:
# X_test_gauss_30
# CPU times: user 1.11 s, sys: 73.5 ms, total: 1.19 s
# Wall time: 1.51 s

# %%
# %%time
add_gauss_to_data(STD_VALS, X_train_origin, 'train')
# Out:
# X_train_gauss_05
# X_train_gauss_10
# X_train_gauss_15
# X_train_gauss_20
# X_train_gauss_25
# X_train_gauss_30
# X_train_gauss_35
# CPU times: user 51.5 s, sys: 4.34 s, total: 55.8 s
# Wall time: 1min 41s

# %% [markdown]
# ## Load the datasets

# %%
def load_gaussian(std_vals, name, X_dict=None):
  
  if not bool(X_dict):
    X_dict = dict()

  stds = [f'{int(val*100):02}' for val in std_vals]
  
  for std_val, std in zip(std_vals, stds):
    print(std_val, std)
    X_dict[std_val] = np.load(ROOT + f'/Adversarial_Data/X_{name}_gauss_{std}.npy') 
  
  return X_dict

# %%
# load the attack examples (test examples) with Gauss noise

X_test_gauss_d = load_gaussian(std_vals=STD_VALS, name='test')
X_test_gauss_d[0.00] = X_test_origin
# Out:
# 0.05 05
# 0.1 10
# 0.15 15
# 0.2 20
# 0.25 25
# 0.3 30
# 0.35 35

# %%
X_train_gauss_d = load_gaussian(std_vals=np.array([0.35]), name='train')
X_train_gauss_d[0.00] = X_train_origin
# Out:
# 0.35 35

# %% [markdown]
# ## Peek at loaded examples

# %%
def show_noise_levels(X_dict, nth_img):
  fig, axes = plt.subplots(ncols=len(X_dict))
  for i, (std, X) in enumerate(sorted(X_dict.items())):
    axes[i].imshow(X[nth_img].reshape((28,28)), cmap=plt.get_cmap('gray'))
    axes[i].set_title(f'noise: {std}')
    axes[i].tick_params(bottom=False, labelbottom=False, left=False, labelleft=False)
    
  fig.set_size_inches(w=10, h=2)
  sns.despine(fig)
  return fig

# %%
fig = show_noise_levels(X_test_gauss_d, np.random.randint(low=0, high=(len(X_test_gauss_d[0]))))

# %% [markdown]
# ## Gaussian Noise Attack

# %%
def plot_degradation(df, model_name, attack_name, xlabel):
  with sns.axes_style('darkgrid'):
    fig, ax = plt.subplots()
  
  sns.lineplot(
      data=df,
      x='var',
      y='value',
      hue='variable',
      hue_order = ['accuracy', 'precision', 'recall'],
      ax=ax,
      palette='mako'
  )
  ax.set_title(f'{model_name} Performance under {attack_name} Attack', size='xx-large', pad=10)
  ax.set_xlabel(xlabel)
  fig.set_size_inches(h=8, w=10)
  return fig

# %%
def attack(model, X_test_d, y_true, attack_name, model_name, xlabel):

  degradation = dict()

  for epsilon, noisy_test_set in X_test_d.items():

    results = model.evaluate(
        x=noisy_test_set,
        y=y_true,
        return_dict=True,
    )

    degradation[epsilon] = results

  # degradation_df = pd.DataFrame.from_dict(degradation, orient='index')
  # degradation_df.index.name='epsilon'

  degradation_df = pd.DataFrame(degradation).transpose().reset_index().rename(columns={'index': 'var'})
  degradation_df = pd.melt(
      degradation_df, 
      id_vars=['var'],
      value_vars=['loss', 'accuracy', 'precision', 'recall']
  )
  return degradation_df, plot_degradation(degradation_df, model_name, attack_name, xlabel)

# %%
gaussian_attack_df, gaussian_attack_fig = attack(
    model=cnn,
    X_test_d=X_test_gauss_d,
    y_true=y_test_origin,
    attack_name='Gaussian Noise',
    model_name='CNN',
    xlabel="epsilon"
)
# Out:
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3062 - accuracy: 0.8898 - precision: 0.9090 - recall: 0.8722
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3872 - accuracy: 0.8587 - precision: 0.8899 - recall: 0.8328
# 588/588 [==============================] - 3s 5ms/step - loss: 0.6266 - accuracy: 0.7831 - precision: 0.8354 - recall: 0.7379
# 588/588 [==============================] - 3s 5ms/step - loss: 1.0498 - accuracy: 0.6748 - precision: 0.7534 - recall: 0.6167
# 588/588 [==============================] - 3s 5ms/step - loss: 1.6016 - accuracy: 0.5576 - precision: 0.6548 - recall: 0.4861
# 588/588 [==============================] - 3s 5ms/step - loss: 2.2552 - accuracy: 0.4403 - precision: 0.5349 - recall: 0.3598
# 588/588 [==============================] - 3s 5ms/step - loss: 2.9382 - accuracy: 0.3298 - precision: 0.4118 - recall: 0.2587
# 588/588 [==============================] - 3s 5ms/step - loss: 0.2802 - accuracy: 0.9021 - precision: 0.9154 - recall: 0.8896

# %%
gaussian_attack_df.to_csv(ROOT + '/attacks/guassian_attack.csv')

# %% [markdown]
# ## Adversarial-training defence

# %% [markdown]
# ### Fit the model

# %%
cnn_gaussian_defence = make_cnn_7conv_1dense('cnn_7conv_1dense_gaussian_defence')
cnn_gaussian_defence.summary()
# Out:
# Model: "cnn_7conv_1dense_gaussian_defence"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 26, 26, 32)        128
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 24, 24, 32)        9248
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 24, 24, 32)        128
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 12, 12, 32)        25632
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 12, 12, 32)        128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 10, 10, 64)        18496
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 10, 10, 64)        256
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 4, 4, 64)          102464
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 4, 4, 64)          256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 1, 1, 128)         131200
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 1, 1, 128)         512
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 47)                6063
# =================================================================
# Total params: 332,015
# Trainable params: 331,183
# Non-trainable params: 832
# _________________________________________________________________

# %%
# %%time

# define callbacks
checkpointer = tf.keras.callbacks.ModelCheckpoint(
    ROOT + '/Models/' + cnn_gaussian_defence._name + '-checkpoint-ep{epoch:02d}-loss{val_loss:.2f}',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1,
)

stopper = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True,
)

lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=2,
    verbose=1,
)

# fit the Model
BATCH_SIZE = 1024,
cnn_gaussian_defence_learning_history = cnn_gaussian_defence.fit(
    x=X_train_gauss_d[0.35], 
    y=y_train_origin,
    validation_split=0.2,
    epochs=50,
    batch_size=32,
    callbacks = [checkpointer, stopper, lr_reducer],
    verbose=1
)

# save the model and training history
model_name = cnn_gaussian_defence._name
cnn_gaussian_defence.save(ROOT+'/Models/'+ model_name)
pd.DataFrame(history_cnn.history).to_csv(ROOT+'/model_histories/'+ model_name + '_history.csv')

# evaluate scores
scores = cnn_gaussian_defence.evaluate(X_test_origin, y_test_origin, verbose=0)

print("Baseline Error: %.2f%%" % (100-scores[1]*100))
print(f'Test loss for base CNN: {scores[0]} / Test scores: {scores[1]}')
# Out:
# Epoch 1/50
# 2819/2820 [============================>.] - ETA: 0s - loss: 0.5737 - accuracy: 0.8069 - precision: 0.8601 - recall: 0.7610
# Epoch 00001: val_accuracy improved from -inf to 0.84145, saving model to /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep01-loss0.44
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep01-loss0.44/assets
# 2820/2820 [==============================] - 22s 8ms/step - loss: 0.5736 - accuracy: 0.8069 - precision: 0.8601 - recall: 0.7610 - val_loss: 0.4427 - val_accuracy: 0.8414 - val_precision: 0.8784 - val_recall: 0.8091
# Epoch 2/50
# 2815/2820 [============================>.] - ETA: 0s - loss: 0.5151 - accuracy: 0.8255 - precision: 0.8698 - recall: 0.7853
# Epoch 00002: val_accuracy improved from 0.84145 to 0.85284, saving model to /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep02-loss0.40
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep02-loss0.40/assets
# 2820/2820 [==============================] - 23s 8ms/step - loss: 0.5150 - accuracy: 0.8255 - precision: 0.8698 - recall: 0.7854 - val_loss: 0.4037 - val_accuracy: 0.8528 - val_precision: 0.8867 - val_recall: 0.8256
# Epoch 3/50
# 2817/2820 [============================>.] - ETA: 0s - loss: 0.4829 - accuracy: 0.8342 - precision: 0.8752 - recall: 0.7965
# Epoch 00003: val_accuracy did not improve from 0.85284
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.4831 - accuracy: 0.8342 - precision: 0.8752 - recall: 0.7964 - val_loss: 0.4131 - val_accuracy: 0.8518 - val_precision: 0.8851 - val_recall: 0.8210
# Epoch 4/50
# 2814/2820 [============================>.] - ETA: 0s - loss: 0.4576 - accuracy: 0.8431 - precision: 0.8806 - recall: 0.8082
# Epoch 00004: val_accuracy improved from 0.85284 to 0.85656, saving model to /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep04-loss0.39
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep04-loss0.39/assets
# 2820/2820 [==============================] - 23s 8ms/step - loss: 0.4577 - accuracy: 0.8431 - precision: 0.8806 - recall: 0.8081 - val_loss: 0.3899 - val_accuracy: 0.8566 - val_precision: 0.8796 - val_recall: 0.8349
# Epoch 5/50
# 2819/2820 [============================>.] - ETA: 0s - loss: 0.4395 - accuracy: 0.8468 - precision: 0.8831 - recall: 0.8140
# Epoch 00005: val_accuracy improved from 0.85656 to 0.85904, saving model to /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep05-loss0.38
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep05-loss0.38/assets
# 2820/2820 [==============================] - 22s 8ms/step - loss: 0.4395 - accuracy: 0.8468 - precision: 0.8831 - recall: 0.8140 - val_loss: 0.3800 - val_accuracy: 0.8590 - val_precision: 0.8850 - val_recall: 0.8368
# Epoch 6/50
# 2817/2820 [============================>.] - ETA: 0s - loss: 0.4250 - accuracy: 0.8506 - precision: 0.8859 - recall: 0.8194
# Epoch 00006: val_accuracy improved from 0.85904 to 0.86888, saving model to /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep06-loss0.36
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep06-loss0.36/assets
# 2820/2820 [==============================] - 23s 8ms/step - loss: 0.4248 - accuracy: 0.8507 - precision: 0.8859 - recall: 0.8195 - val_loss: 0.3557 - val_accuracy: 0.8689 - val_precision: 0.8978 - val_recall: 0.8418
# Epoch 7/50
# 2816/2820 [============================>.] - ETA: 0s - loss: 0.4114 - accuracy: 0.8549 - precision: 0.8880 - recall: 0.8248
# Epoch 00007: val_accuracy did not improve from 0.86888
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.4115 - accuracy: 0.8549 - precision: 0.8879 - recall: 0.8248 - val_loss: 0.3663 - val_accuracy: 0.8653 - val_precision: 0.8904 - val_recall: 0.8440
# Epoch 8/50
# 2818/2820 [============================>.] - ETA: 0s - loss: 0.4018 - accuracy: 0.8584 - precision: 0.8907 - recall: 0.8286
# Epoch 00008: val_accuracy did not improve from 0.86888
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.4017 - accuracy: 0.8584 - precision: 0.8907 - recall: 0.8286 - val_loss: 0.3650 - val_accuracy: 0.8656 - val_precision: 0.8849 - val_recall: 0.8494
# Epoch 9/50
# 2813/2820 [============================>.] - ETA: 0s - loss: 0.3583 - accuracy: 0.8720 - precision: 0.9002 - recall: 0.8445
# Epoch 00009: val_accuracy improved from 0.86888 to 0.87863, saving model to /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep09-loss0.33
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep09-loss0.33/assets
# 2820/2820 [==============================] - 23s 8ms/step - loss: 0.3582 - accuracy: 0.8720 - precision: 0.9002 - recall: 0.8446 - val_loss: 0.3283 - val_accuracy: 0.8786 - val_precision: 0.8990 - val_recall: 0.8598
# Epoch 10/50
# 2819/2820 [============================>.] - ETA: 0s - loss: 0.3444 - accuracy: 0.8747 - precision: 0.9037 - recall: 0.8493
# Epoch 00010: val_accuracy improved from 0.87863 to 0.87996, saving model to /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep10-loss0.32
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep10-loss0.32/assets
# 2820/2820 [==============================] - 23s 8ms/step - loss: 0.3444 - accuracy: 0.8747 - precision: 0.9037 - recall: 0.8493 - val_loss: 0.3243 - val_accuracy: 0.8800 - val_precision: 0.9006 - val_recall: 0.8624
# Epoch 11/50
# 2813/2820 [============================>.] - ETA: 0s - loss: 0.3353 - accuracy: 0.8792 - precision: 0.9051 - recall: 0.8543
# Epoch 00011: val_accuracy did not improve from 0.87996
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.3354 - accuracy: 0.8791 - precision: 0.9050 - recall: 0.8543 - val_loss: 0.3279 - val_accuracy: 0.8797 - val_precision: 0.8982 - val_recall: 0.8619
# Epoch 12/50
# 2818/2820 [============================>.] - ETA: 0s - loss: 0.3307 - accuracy: 0.8800 - precision: 0.9063 - recall: 0.8548
# Epoch 00012: val_accuracy improved from 0.87996 to 0.88027, saving model to /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep12-loss0.32
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep12-loss0.32/assets
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 2820/2820 [==============================] - 23s 8ms/step - loss: 0.3309 - accuracy: 0.8800 - precision: 0.9063 - recall: 0.8549 - val_loss: 0.3248 - val_accuracy: 0.8803 - val_precision: 0.9010 - val_recall: 0.8610
# Epoch 13/50
# 2814/2820 [============================>.] - ETA: 0s - loss: 0.3226 - accuracy: 0.8810 - precision: 0.9073 - recall: 0.8562
# Epoch 00013: val_accuracy improved from 0.88027 to 0.88116, saving model to /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep13-loss0.32
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep13-loss0.32/assets
# 2820/2820 [==============================] - 23s 8ms/step - loss: 0.3228 - accuracy: 0.8810 - precision: 0.9072 - recall: 0.8562 - val_loss: 0.3223 - val_accuracy: 0.8812 - val_precision: 0.9007 - val_recall: 0.8627
# Epoch 14/50
# 2818/2820 [============================>.] - ETA: 0s - loss: 0.3185 - accuracy: 0.8840 - precision: 0.9092 - recall: 0.8599
# Epoch 00014: val_accuracy improved from 0.88116 to 0.88147, saving model to /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep14-loss0.32
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep14-loss0.32/assets
# 2820/2820 [==============================] - 23s 8ms/step - loss: 0.3185 - accuracy: 0.8840 - precision: 0.9092 - recall: 0.8600 - val_loss: 0.3219 - val_accuracy: 0.8815 - val_precision: 0.9019 - val_recall: 0.8625
# Epoch 15/50
# 2817/2820 [============================>.] - ETA: 0s - loss: 0.3189 - accuracy: 0.8834 - precision: 0.9089 - recall: 0.8605
# Epoch 00015: val_accuracy improved from 0.88147 to 0.88214, saving model to /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep15-loss0.32
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep15-loss0.32/assets
# 2820/2820 [==============================] - 23s 8ms/step - loss: 0.3188 - accuracy: 0.8834 - precision: 0.9089 - recall: 0.8604 - val_loss: 0.3219 - val_accuracy: 0.8821 - val_precision: 0.9027 - val_recall: 0.8637
# Epoch 16/50
# 2813/2820 [============================>.] - ETA: 0s - loss: 0.3126 - accuracy: 0.8858 - precision: 0.9101 - recall: 0.8629
# Epoch 00016: val_accuracy did not improve from 0.88214
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.3126 - accuracy: 0.8858 - precision: 0.9100 - recall: 0.8629 - val_loss: 0.3221 - val_accuracy: 0.8820 - val_precision: 0.9015 - val_recall: 0.8641
# Epoch 17/50
# 2818/2820 [============================>.] - ETA: 0s - loss: 0.3131 - accuracy: 0.8845 - precision: 0.9100 - recall: 0.8608
# Epoch 00017: val_accuracy did not improve from 0.88214
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.3131 - accuracy: 0.8845 - precision: 0.9100 - recall: 0.8608 - val_loss: 0.3217 - val_accuracy: 0.8821 - val_precision: 0.9020 - val_recall: 0.8641
# Epoch 18/50
# 2819/2820 [============================>.] - ETA: 0s - loss: 0.3123 - accuracy: 0.8845 - precision: 0.9097 - recall: 0.8606
# Epoch 00018: val_accuracy did not improve from 0.88214
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.3123 - accuracy: 0.8845 - precision: 0.9097 - recall: 0.8605 - val_loss: 0.3218 - val_accuracy: 0.8820 - val_precision: 0.9016 - val_recall: 0.8640
# Epoch 19/50
# 2819/2820 [============================>.] - ETA: 0s - loss: 0.3109 - accuracy: 0.8858 - precision: 0.9111 - recall: 0.8629
# Epoch 00019: val_accuracy improved from 0.88214 to 0.88231, saving model to /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep19-loss0.32
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep19-loss0.32/assets
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 2820/2820 [==============================] - 23s 8ms/step - loss: 0.3110 - accuracy: 0.8857 - precision: 0.9111 - recall: 0.8628 - val_loss: 0.3221 - val_accuracy: 0.8823 - val_precision: 0.9016 - val_recall: 0.8643
# Epoch 20/50
# 2814/2820 [============================>.] - ETA: 0s - loss: 0.3118 - accuracy: 0.8863 - precision: 0.9103 - recall: 0.8625
# Epoch 00020: val_accuracy did not improve from 0.88231
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.3117 - accuracy: 0.8862 - precision: 0.9103 - recall: 0.8625 - val_loss: 0.3216 - val_accuracy: 0.8820 - val_precision: 0.9018 - val_recall: 0.8645
# Epoch 21/50
# 2819/2820 [============================>.] - ETA: 0s - loss: 0.3111 - accuracy: 0.8869 - precision: 0.9117 - recall: 0.8637
# Epoch 00021: val_accuracy did not improve from 0.88231
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.3111 - accuracy: 0.8869 - precision: 0.9117 - recall: 0.8638 - val_loss: 0.3214 - val_accuracy: 0.8821 - val_precision: 0.9016 - val_recall: 0.8647
# Epoch 22/50
# 2815/2820 [============================>.] - ETA: 0s - loss: 0.3109 - accuracy: 0.8861 - precision: 0.9101 - recall: 0.8627
# Epoch 00022: val_accuracy did not improve from 0.88231
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.3109 - accuracy: 0.8861 - precision: 0.9101 - recall: 0.8627 - val_loss: 0.3219 - val_accuracy: 0.8818 - val_precision: 0.9020 - val_recall: 0.8642
# Epoch 23/50
# 2818/2820 [============================>.] - ETA: 0s - loss: 0.3136 - accuracy: 0.8850 - precision: 0.9096 - recall: 0.8615
# Epoch 00023: val_accuracy did not improve from 0.88231
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.3137 - accuracy: 0.8850 - precision: 0.9096 - recall: 0.8615 - val_loss: 0.3220 - val_accuracy: 0.8821 - val_precision: 0.9018 - val_recall: 0.8641
# Epoch 24/50
# 2819/2820 [============================>.] - ETA: 0s - loss: 0.3124 - accuracy: 0.8838 - precision: 0.9090 - recall: 0.8613
# Epoch 00024: val_accuracy did not improve from 0.88231
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.3124 - accuracy: 0.8837 - precision: 0.9090 - recall: 0.8613 - val_loss: 0.3220 - val_accuracy: 0.8819 - val_precision: 0.9016 - val_recall: 0.8646
# Epoch 25/50
# 2816/2820 [============================>.] - ETA: 0s - loss: 0.3100 - accuracy: 0.8856 - precision: 0.9104 - recall: 0.8618
# Epoch 00025: val_accuracy did not improve from 0.88231
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.3100 - accuracy: 0.8856 - precision: 0.9104 - recall: 0.8618 - val_loss: 0.3218 - val_accuracy: 0.8818 - val_precision: 0.9016 - val_recall: 0.8642
# Epoch 26/50
# 2820/2820 [==============================] - ETA: 0s - loss: 0.3104 - accuracy: 0.8862 - precision: 0.9103 - recall: 0.8636
# Epoch 00026: val_accuracy did not improve from 0.88231
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.3104 - accuracy: 0.8862 - precision: 0.9103 - recall: 0.8636 - val_loss: 0.3214 - val_accuracy: 0.8819 - val_precision: 0.9016 - val_recall: 0.8644
# Epoch 27/50
# 2819/2820 [============================>.] - ETA: 0s - loss: 0.3106 - accuracy: 0.8852 - precision: 0.9101 - recall: 0.8617
# Epoch 00027: val_accuracy improved from 0.88231 to 0.88267, saving model to /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep27-loss0.32
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence-checkpoint-ep27-loss0.32/assets
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 2820/2820 [==============================] - 23s 8ms/step - loss: 0.3106 - accuracy: 0.8853 - precision: 0.9101 - recall: 0.8617 - val_loss: 0.3216 - val_accuracy: 0.8827 - val_precision: 0.9015 - val_recall: 0.8647
# Epoch 28/50
# 2816/2820 [============================>.] - ETA: 0s - loss: 0.3111 - accuracy: 0.8857 - precision: 0.9098 - recall: 0.8632
# Epoch 00028: val_accuracy did not improve from 0.88267
# 2820/2820 [==============================] - 21s 7ms/step - loss: 0.3111 - accuracy: 0.8857 - precision: 0.9097 - recall: 0.8632 - val_loss: 0.3217 - val_accuracy: 0.8821 - val_precision: 0.9020 - val_recall: 0.8641
# Epoch 29/50
# 2817/2820 [============================>.] - ETA: 0s - loss: 0.3124 - accuracy: 0.8854 - precision: 0.9099 - recall: 0.8626
# Epoch 00029: val_accuracy did not improve from 0.88267
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.3124 - accuracy: 0.8854 - precision: 0.9099 - recall: 0.8626 - val_loss: 0.3216 - val_accuracy: 0.8821 - val_precision: 0.9018 - val_recall: 0.8646
# Epoch 30/50
# 2815/2820 [============================>.] - ETA: 0s - loss: 0.3152 - accuracy: 0.8846 - precision: 0.9098 - recall: 0.8610
# Epoch 00030: val_accuracy did not improve from 0.88267
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.3152 - accuracy: 0.8846 - precision: 0.9098 - recall: 0.8610 - val_loss: 0.3217 - val_accuracy: 0.8818 - val_precision: 0.9014 - val_recall: 0.8644
# Epoch 31/50
# 2813/2820 [============================>.] - ETA: 0s - loss: 0.3090 - accuracy: 0.8858 - precision: 0.9102 - recall: 0.8636
# Epoch 00031: val_accuracy did not improve from 0.88267
# Restoring model weights from the end of the best epoch.
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# 2820/2820 [==============================] - 20s 7ms/step - loss: 0.3088 - accuracy: 0.8858 - precision: 0.9102 - recall: 0.8636 - val_loss: 0.3216 - val_accuracy: 0.8820 - val_precision: 0.9015 - val_recall: 0.8643
# Epoch 00031: early stopping
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Models/cnn_7conv_1dense_gaussian_defence/assets
# Baseline Error: 11.48%
# Test loss for base CNN: 0.32401859760284424 / Test scores: 0.885212779045105
# CPU times: user 12min 56s, sys: 1min 23s, total: 14min 20s
# Wall time: 11min 6s

# %% [markdown]
# ### Learning curves

# %%
show_learning_curve(
    cnn_gaussian_defence_learning_history, 
    clf_name='CNN adversarially-trained on Gaussian Noise'
)

# %%
with sns.axes_style('darkgrid'):

  fig, ax = plt.subplots()
  sns.lineplot(
    data=cnn_gaussian_defence_learning_history.history,
    ax=ax,
    dashes=True,
    # dashes=[False, True, False, True,False, True],
    hue_order=[
      'accuracy',
      'val_accuracy',
      'loss',
      'val_loss',
      # 'lr',
    ],
    palette='mako',
  )

  ax.set_title('CNN Learning Curve', size='xx-large', pad=10,)
  ax.set_xlabel('# epochs')
  ax.set_ylabel('Accuracy / Loss')

# %% [markdown]
# ### Confusion Matrix

# %%
fig =show_confusion(cnn_gaussian_defence, epsilon=0.0)
# Out:
# WARNING:tensorflow:From <ipython-input-144-b2a6747bcf04>:5: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %% [markdown]
# ### Attack on adversarially-trained model

# %%
gauss_defence_df, guass_defence_fig = noise_attack(
    model=cnn_gaussian_defence,
    X_test_d=X_test_gauss_d,
    y_true=y_test_origin,
    adversary_variable_name='epsilon',
    attack_name='Gaussian Noise',
    model_name='Adversarially-trained CNN',
)
# Out:
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3194 - accuracy: 0.8868 - precision: 0.9023 - recall: 0.8744
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3174 - accuracy: 0.8890 - precision: 0.9040 - recall: 0.8771
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3178 - accuracy: 0.8894 - precision: 0.9041 - recall: 0.8771
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3208 - accuracy: 0.8890 - precision: 0.9063 - recall: 0.8777
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3239 - accuracy: 0.8869 - precision: 0.9048 - recall: 0.8731
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3314 - accuracy: 0.8853 - precision: 0.9032 - recall: 0.8696
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3418 - accuracy: 0.8814 - precision: 0.9013 - recall: 0.8649
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3240 - accuracy: 0.8852 - precision: 0.9012 - recall: 0.8729

# %%
def show_adversary_degradation(model, adv_d, adversary_kind, model_kind):
  adv_degradation = dict()
  for adv_amount, adv_test_set in adv_d.items():

    results = model.evaluate(
        x=adv_test_set,
        y=y_test_origin,
        return_dict=True,
    )

    adv_degradation[adv_amount] = results

  adv_degradation_df = pd.DataFrame(adv_degradation).transpose().reset_index().rename(columns={'index': 'epsilon'})
  adv_degradation_df = pd.melt(
      adv_degradation_df, 
      id_vars=['epsilon'],
      value_vars=['loss', 'accuracy', 'precision', 'recall']
  )

  fig, ax = plt.subplots()
  sns.lineplot(
      data=adv_degradation_df,
      x='epsilon',
      y='value',
      hue='variable',
      hue_order = ['accuracy', 'precision', 'recall'],
      ax=ax,
      palette='mako'
  )
  ax.set_title(f'{model_kind} Accuracy on {adversary_kind} Characters', size='xx-large', pad=10)
  ax.set_xlabel(r'$\epsilon \quad \left(\rm{noise} \sim N\left(0, \epsilon^{2}\right)\right)$', size='large')
  ax.set_ylabel('value', size='large')
  fig.set_size_inches(h=8, w=10)

# %%
with sns.axes_style('darkgrid'):
  show_adversary_degradation(
      model=cnn_gaussian_defence, 
      adv_d=X_test_gauss_d,
      adversary_kind='Gaussian Noise',
      model_kind='Adversarially-Trained CNN'
  )
# Out:
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3082 - accuracy: 0.8905 - precision: 0.9071 - recall: 0.8779
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3082 - accuracy: 0.8911 - precision: 0.9071 - recall: 0.8780
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3093 - accuracy: 0.8910 - precision: 0.9068 - recall: 0.8778
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3139 - accuracy: 0.8898 - precision: 0.9072 - recall: 0.8771
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3164 - accuracy: 0.8876 - precision: 0.9051 - recall: 0.8740
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3222 - accuracy: 0.8845 - precision: 0.9027 - recall: 0.8702
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3364 - accuracy: 0.8818 - precision: 0.9031 - recall: 0.8638
# 588/588 [==============================] - 3s 5ms/step - loss: 0.3097 - accuracy: 0.8905 - precision: 0.9071 - recall: 0.8770

# %% [markdown]
# # FGSM Attack

# %%
cnn.trainable = False

# %% [markdown]
# ## Show process

# %%
image = X_test_origin[0].reshape((1,28,28,1))
image_probs = cnn.predict(image)

# %%
plt.imshow(image.reshape((28,28)), cmap=plt.get_cmap('gray'))

# %%
loss_object = tf.keras.losses.CategoricalCrossentropy()

def create_adversarial_pattern(input_image, input_label, model):
  input_image = tf.convert_to_tensor(input_image)
  with tf.GradientTape() as tape:
    tape.watch(input_image)
    prediction = model(input_image)
    loss= loss_object(input_label, prediction)
  
  # get gradient of loss w.r.t image
  gradient = tape.gradient(loss, input_image)
  signed_grad = tf.sign(gradient)
  return signed_grad

# %%
label = y_test_origin[0].reshape((1,47))
perturbations = create_adversarial_pattern(image, label, cnn).numpy()

# %%
plt.imshow((perturbations).reshape((28,28)), cmap=plt.get_cmap('gray'))

# %%
plt.imshow((image + 0.1 *perturbations).reshape((28,28)), cmap=plt.get_cmap('gray'))

# %% [markdown]
# ## Create adversarial examples on original CNN

# %%
def create_fgsm(model, X, y, store_dir, description):
  
  fgsm_perturbation = np.zeros(shape=X.shape)

  for i, img in enumerate(X):
    img = np.expand_dims(img, 0)
    lbl = np.expand_dims(y[i], 0)
    fgsm_perturbation[i] = create_adversarial_pattern(img, lbl, model)
  fname = store_dir + f'/{description}_fgsm_from_{model._name}'
  np.save(fname, fgsm_perturbation)
  return fgsm_perturbation

# %%
# %%time
X_test_fgsm_perturbs = create_fgsm(
    model=cnn,
    X=X_test_origin, 
    y=y_test_origin,
    store_dir=ROOT + '/Adversarial_Data/',
    description='X_test'
)
# Out:
# CPU times: user 4min 13s, sys: 2.7 s, total: 4min 16s
# Wall time: 4min 12s

# %%
def add_perturbations(epsilons, perturbations, X, X_dict=None):
  if not bool(X_dict):
    X_dict = dict()
  
  for eps in epsilons:
    X_dict[eps] = X + eps * perturbations * (np.sqrt(13) - 1)/2 # normalizing factor so each FGSM pixel has roughly same variance as Gaussian for the same epsilon
  
  X_dict[0.0] = X
  return X_dict

# %%
epsilons = [0.001, 0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35]

X_test_fgsm_d = add_perturbations(epsilons, X_test_fgsm_perturbs, X_test_origin)

# %% [markdown]
# ## Peek at generated examples

# %%
show_9_samples(X_test_fgsm_d[0.1])
# Out:
# Randomly selected indices:  [13414  7343  2786  7234 16767   517 16544 15301 12493]

# %% [markdown]
# ## Load adversarial examples

# %%
perturbs = np.load(ROOT + f'/Adversarial_Data/X_test_fgsm_from_cnn_7conv_1dense.npy')

# %%
epsilons = [0.001, 0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35]

X_test_fgsm_d = add_perturbations(epsilons, perturbs, X_test_origin)

# %% [markdown]
# ## FGSM attack

# %%
fgsm_attack_df, fgsm_attack_fig = attack(
    model=cnn,
    X_test_d=X_test_fgsm_d,
    y_true=y_test_origin,
    attack_name='FGSM',
    model_name='CNN',
    xlabel='epsilon'
)
# Out:
# 588/588 [==============================] - 2s 4ms/step - loss: 0.2921 - accuracy: 0.8975 - precision: 0.9118 - recall: 0.8854
# 588/588 [==============================] - 2s 4ms/step - loss: 0.4162 - accuracy: 0.8539 - precision: 0.8709 - recall: 0.8405
# 588/588 [==============================] - 2s 4ms/step - loss: 1.4417 - accuracy: 0.5796 - precision: 0.6187 - recall: 0.5475
# 588/588 [==============================] - 3s 4ms/step - loss: 7.8892 - accuracy: 0.1465 - precision: 0.1655 - recall: 0.1303
# 588/588 [==============================] - 3s 4ms/step - loss: 15.2557 - accuracy: 0.0569 - precision: 0.0589 - recall: 0.0527
# 588/588 [==============================] - 2s 4ms/step - loss: 22.4537 - accuracy: 0.0339 - precision: 0.0343 - recall: 0.0324
# 588/588 [==============================] - 3s 4ms/step - loss: 29.7277 - accuracy: 0.0246 - precision: 0.0244 - recall: 0.0237
# 588/588 [==============================] - 2s 4ms/step - loss: 37.1288 - accuracy: 0.0206 - precision: 0.0205 - recall: 0.0202
# 588/588 [==============================] - 2s 4ms/step - loss: 44.6584 - accuracy: 0.0187 - precision: 0.0186 - recall: 0.0185
# 588/588 [==============================] - 2s 4ms/step - loss: 0.2802 - accuracy: 0.9021 - precision: 0.9154 - recall: 0.8896

# %%
fgsm_attack_df.to_csv(ROOT+'/attacks/fgsm_attack.csv')
fgsm_attack_df = pd.read_csv(ROOT+'/attacks/fgsm_attack.csv')
# Out:
#     Unnamed: 0    var   variable      value
# 0            0  0.001       loss   0.292113
# 1            1  0.010       loss   0.416157
# 2            2  0.050       loss   1.441710
# 3            3  0.100       loss   7.889174
# 4            4  0.150       loss  15.255693
# 5            5  0.200       loss  22.453695
# 6            6  0.250       loss  29.727747
# 7            7  0.300       loss  37.128788
# 8            8  0.350       loss  44.658386
# 9            9  0.000       loss   0.280185
# 10          10  0.001   accuracy   0.897500
# 11          11  0.010   accuracy   0.853936
# 12          12  0.050   accuracy   0.579574
# 13          13  0.100   accuracy   0.146489
# 14          14  0.150   accuracy   0.056862
# 15          15  0.200   accuracy   0.033936
# 16          16  0.250   accuracy   0.024628
# 17          17  0.300   accuracy   0.020638
# 18          18  0.350   accuracy   0.018723
# 19          19  0.000   accuracy   0.902128
# 20          20  0.001  precision   0.911810
# 21          21  0.010  precision   0.870921
# 22          22  0.050  precision   0.618681
# 23          23  0.100  precision   0.165451
# 24          24  0.150  precision   0.058907
# 25          25  0.200  precision   0.034279
# 26          26  0.250  precision   0.024410
# 27          27  0.300  precision   0.020532
# 28          28  0.350  precision   0.018622
# 29          29  0.000  precision   0.915430
# 30          30  0.001     recall   0.885426
# 31          31  0.010     recall   0.840532
# 32          32  0.050     recall   0.547500
# 33          33  0.100     recall   0.130266
# 34          34  0.150     recall   0.052713
# 35          35  0.200     recall   0.032394
# 36          36  0.250     recall   0.023723
# 37          37  0.300     recall   0.020213
# 38          38  0.350     recall   0.018457
# 39          39  0.000     recall   0.889574

# %% [markdown]
# # FGSM Adversarial Training Defense

# %% [markdown]
# # FGSM Randomized Shifting Defense

# %% [markdown]
# ## Visualize random shifting

# %%
random_shifter = tf.keras.preprocessing.image.ImageDataGenerator(
    fill_mode='constant',
    cval=0,
    height_shift_range=5,
    width_shift_range=5,
    zoom_range=[1, 1],
    data_format='channels_last'
)

# %%
img = X_train_origin[100]
samples = np.expand_dims(img, 0)

iter = random_shifter.flow(samples, batch_size=2)

for i in range(9):
  plt.subplot(330 + 1 + i)
  batch = iter.next()
  image = batch[0]
  plt.imshow(
      image.reshape((28,28)), 
      cmap=plt.get_cmap('gray'),
  )
plt.show()

# %% [markdown]
# ## Defense

# %%
fgsm_degradation = dict()

shift_range = [0,2,4]
top_zoom_range = [1.0, 1.1, 1.2]
epsilon_range = [0, 0.1, 0.2]

for eps in epsilon_range:
  
  fgsm_degradation[eps] = dict()

  for shift in shift_range:

    fgsm_degradation[eps][shift] = dict()
    
    for zoom_upper in top_zoom_range:

      random_shifter = tf.keras.preprocessing.image.ImageDataGenerator(
        fill_mode='constant',
        cval=0,
        height_shift_range=shift,
        width_shift_range=shift,
        zoom_range=[1.0, zoom_upper],
        data_format='channels_last'
      ) 

      result = cnn.evaluate(
          random_shifter.flow(X_test_fgsm_d[eps], y_test_origin),
          return_dict=True,
      )

      fgsm_degradation[eps][shift][zoom_upper] = result

fgsm_degradation_df = pd.DataFrame.from_dict(
    {
        (eps, shift, zoom_upper): fgsm_degradation[eps][shift][zoom_upper]
        for eps in fgsm_degradation.keys()
        for shift in fgsm_degradation[eps].keys()
        for zoom_upper in fgsm_degradation[eps][shift].keys()
    },
    orient='index',
)
fgsm_degradation_df.index.names = ['epsilon', 'shift', 'zoom_upper']
# Out:
# 588/588 [==============================] - 3s 5ms/step - loss: 0.2802 - accuracy: 0.9021 - precision: 0.9154 - recall: 0.8896
# 588/588 [==============================] - 5s 9ms/step - loss: 0.2968 - accuracy: 0.8941 - precision: 0.9105 - recall: 0.8796
# 588/588 [==============================] - 5s 9ms/step - loss: 0.3174 - accuracy: 0.8831 - precision: 0.9026 - recall: 0.8693
# 588/588 [==============================] - 6s 10ms/step - loss: 0.2977 - accuracy: 0.8950 - precision: 0.9111 - recall: 0.8782
# 588/588 [==============================] - 7s 11ms/step - loss: 0.3140 - accuracy: 0.8884 - precision: 0.9090 - recall: 0.8720
# 588/588 [==============================] - 6s 11ms/step - loss: 0.3288 - accuracy: 0.8789 - precision: 0.9008 - recall: 0.8640
# 588/588 [==============================] - 6s 11ms/step - loss: 0.5311 - accuracy: 0.8285 - precision: 0.8635 - recall: 0.8000
# 588/588 [==============================] - 7s 11ms/step - loss: 0.5086 - accuracy: 0.8321 - precision: 0.8694 - recall: 0.8051
# 588/588 [==============================] - 6s 11ms/step - loss: 0.4703 - accuracy: 0.8362 - precision: 0.8709 - recall: 0.8100
# 588/588 [==============================] - 3s 5ms/step - loss: 7.8892 - accuracy: 0.1465 - precision: 0.1655 - recall: 0.1303
# 588/588 [==============================] - 5s 9ms/step - loss: 5.4294 - accuracy: 0.2283 - precision: 0.2727 - recall: 0.2030
# 588/588 [==============================] - 5s 9ms/step - loss: 5.1132 - accuracy: 0.2402 - precision: 0.2902 - recall: 0.2124
# 588/588 [==============================] - 6s 10ms/step - loss: 7.8788 - accuracy: 0.1530 - precision: 0.1720 - recall: 0.1351
# 588/588 [==============================] - 7s 11ms/step - loss: 5.3898 - accuracy: 0.2346 - precision: 0.2792 - recall: 0.2076
# 588/588 [==============================] - 7s 11ms/step - loss: 5.1061 - accuracy: 0.2442 - precision: 0.2907 - recall: 0.2141
# 588/588 [==============================] - 6s 11ms/step - loss: 8.2855 - accuracy: 0.1291 - precision: 0.1453 - recall: 0.1138
# 588/588 [==============================] - 7s 11ms/step - loss: 5.5382 - accuracy: 0.2183 - precision: 0.2617 - recall: 0.1893
# 588/588 [==============================] - 7s 11ms/step - loss: 5.2033 - accuracy: 0.2298 - precision: 0.2801 - recall: 0.2011
# 588/588 [==============================] - 3s 5ms/step - loss: 22.4537 - accuracy: 0.0339 - precision: 0.0343 - recall: 0.0324
# 588/588 [==============================] - 5s 9ms/step - loss: 17.8265 - accuracy: 0.0424 - precision: 0.0429 - recall: 0.0389
# 588/588 [==============================] - 5s 9ms/step - loss: 17.4723 - accuracy: 0.0429 - precision: 0.0435 - recall: 0.0393
# 588/588 [==============================] - 6s 10ms/step - loss: 22.5944 - accuracy: 0.0348 - precision: 0.0351 - recall: 0.0331
# 588/588 [==============================] - 7s 11ms/step - loss: 17.8329 - accuracy: 0.0441 - precision: 0.0446 - recall: 0.0404
# 588/588 [==============================] - 7s 11ms/step - loss: 17.4197 - accuracy: 0.0428 - precision: 0.0434 - recall: 0.0393
# 588/588 [==============================] - 6s 10ms/step - loss: 22.9970 - accuracy: 0.0324 - precision: 0.0326 - recall: 0.0310
# 588/588 [==============================] - 6s 11ms/step - loss: 17.7523 - accuracy: 0.0400 - precision: 0.0408 - recall: 0.0373
# 588/588 [==============================] - 7s 11ms/step - loss: 17.1457 - accuracy: 0.0397 - precision: 0.0399 - recall: 0.0362

# %%
fgsm_degradation_df.to_csv(ROOT+'/attacks/fgsm_randomized_defence_1.csv')
fgsm_degradation_df = pd.read_csv(ROOT+'/attacks/fgsm_randomized_defence_1.csv')

# %%
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset

with sns.axes_style('whitegrid'):
  fig, ax = plt.subplots()
fig.set_size_inches(h=7, w=10)
sns.lineplot(
    x='epsilon',
    y='accuracy',
    hue='zoom_upper',
    style='shift',
    markers=False,
    dashes=False,
    size='shift',
    sizes=(0.5, 3),
    ax=ax,
    palette=sns.color_palette('mako', 7)[0:7:3],
    data=fgsm_degradation_df,
    legend=False,
)
ax.legend(loc='lower left')

with sns.axes_style('darkgrid'):
  axins = zoomed_inset_axes(ax, zoom=2.5, loc='upper right')

sns.lineplot(
    x='epsilon',
    y='accuracy',
    hue='zoom_upper',
    style='shift',
    markers=False,
    dashes=False,
    size='shift',
    sizes=(1, 5),
    ax=axins,
    palette=sns.color_palette('mako', 7)[0:7:3],
    data=fgsm_degradation_df,
    legend=True,
)


axins.set_xlim(left=0.085, right=0.115)
axins.set_ylim(top=0.3, bottom=0.00)
axins.yaxis.get_major_locator().set_params(nbins=4)
axins.xaxis.get_major_locator().set_params(nbins=4)

mark_inset(ax, axins,loc1=2,loc2=4, fc='none',ec='0.5')

plt.setp(axins.get_xticklabels(), visible=False)
plt.setp(axins.get_yticklabels(), visible=False)
# Out:
# No handles with labels found to put in legend.
# [None, None, None, None, None, None, None, None]

# %%
# Out:
# (0.0, 0.3)

# %%
sns.scatterplot(
    data=fgsm_degradation_df,
    x='shift',
    y='zoom_upper',
    hue='accuracy',
    size='accuracy'
)

# %% [markdown]
# # Setup augmented data generator

# %%
augmentation_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    fill_mode='constant',
    cval=0,
    height_shift_range=3,
    width_shift_range=3,
    # shear_range=20,
    # rotation_range=20,
    # zoom_range=0.2,
    data_format='channels_last',
    # rescale=1.0/255,
)

# %% [markdown]
# ## Visualise the data augmentations

# %%
# original
img = X_train_origin[100]
plt.imshow(img.reshape((28, 28)), cmap=plt.get_cmap('gray'))

# %%
# randomised
samples = np.expand_dims(img, 0)

iter = augmentation_generator.flow(samples, batch_size=2)

for i in range(9):
  plt.subplot(330 + 1 + i)
  batch = iter.next()
  image = batch[0]
  plt.imshow(
      image.reshape((28,28)), 
      cmap=plt.get_cmap('gray'),
  )
plt.show()

# %% [markdown]
# ## Visualise the data augmentations

# %%
# original
img = X_train_origin[100]
plt.imshow(img.reshape((28, 28)), cmap=plt.get_cmap('gray'))

# %%
# randomised
samples = np.expand_dims(img, 0)

iter = augmentation_generator.flow(samples, batch_size=2)

for i in range(9):
  plt.subplot(330 + 1 + i)
  batch = iter.next()
  image = batch[0]
  plt.imshow(
      image.reshape((28,28)), 
      cmap=plt.get_cmap('gray'),
  )
plt.show()
